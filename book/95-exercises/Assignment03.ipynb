# %% [markdown]
# # Assignment 03
# Due Sep 19, 2024
#
# 1. Execute the four scrips in ../examples that create four example databases.
# * The [University Database](../examples/000-university-database.ipynb)
# * The [Sales Database](../examples/010-sales-database.ipynb)
# * The [App Database](../examples/020-app-database.ipynb)
# * The [Nation Database](../examples/030-nations-database.ipynb)
# * The [Hotel Database](../examples/040-hotel-database.ipynb)
#
# 2. Explore the contents of the databases.
#
# 3. Update the university database to populate at least 1000 students and populate
#
# 4. Write the following queries
#
#   * (University) Show the names all students from Texas
#   * (Sales) Show all products with the buy price exceeding $100.00
#   * (Nations)  Show all countries that are bigger than 1/2 million square km.

# %%
import datajoint as dj
schema = dj.Schema('university')

# %%
schema.spawn_missing_classes()
dj.Diagram(schema)

# %%
Student() & 'sex="F"' & "date_of_birth < '2000-01-01'"
# Out:
# *student_id    first_name     last_name      sex     date_of_birth  home_address   home_city      home_state     home_zip     home_phone
# +------------+ +------------+ +------------+ +-----+ +------------+ +------------+ +------------+ +------------+ +----------+ +------------+
# 107            Sarah          Cooper         F       1992-08-21     557 Schneider  West Jasmine   AZ             18845        (798)315-3761
# 111            Tanya          Woods          F       1989-12-01     152 White Unio Port Phillip   MD             51697        595-396-7241x0
# 115            Wendy          Weber          F       1991-09-24     712 Frank Forg West Philipche HI             41409        559.670.9679
# 119            Melissa        Morales        F       1994-08-04     416 Mooney Tra Port Amanda    PR             57910        9762146483
# 122            Brenda         Garcia         F       1997-01-31     91271 Michael  South Gregg    AK             56411        +1-374-296-187
# ...

# %%
# %%sql
#
# SELECT * FROM `unversity`.`student` WHERE home_state="TX"
# Out:
# UsageError: Cell magic `%%sql` not found.
